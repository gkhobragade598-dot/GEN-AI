# %%
pip install -U langchain langchain-openai openai
# Out:
# Requirement already satisfied: langchain in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (1.3.14)
# Requirement already satisfied: langchain-openai in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (1.4.1)
# Requirement already satisfied: openai in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (2.48.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.9 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain) (1.5.1)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain) (1.2.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.10.10)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.8.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.8)
# Requirement already satisfied: websockets<16,>=14 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (4.13.0)
# Requirement already satisfied: distro>=1.7.0 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.33.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (0.25.0)
# Requirement already satisfied: certifi in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from openai) (0.13.0)
# Requirement already satisfied: tqdm>4 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from openai) (4.67.3)
# Requirement already satisfied: regex in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.7.19)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.6.3)
# Requirement already satisfied: colorama in c:\users\gkhob\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os 
from langchain.chat_models import init_chat_model

os.environ["OPEN_API_KEY"] = "OPEN_API_KEY"


model = init_chat_model("gpt-5.4-mini")

# %%
from openai import RateLimitError

try:
    response = model.invoke("job opportunity in 2027")
except RateLimitError as e:
    response = f"OpenAI API quota/rate limit exceeded: {e}"
print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 response = model.invoke("job opportunity in 2027")
#       2 print(response)
#
# File c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\langchain_openai\chat_models\base.py:1747, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1745     _handle_openai_bad_request(e)
#    1746 except openai.APIError as e:
# -> 1747     _handle_openai_api_error(e)
#    1748 except Exception as e:
#    1749     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\langchain_openai\chat_models\base.py:1742, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1735         return _construct_lc_result_from_responses_api(
#    1736             response,
#    1737             schema=original_schema_obj,
#    1738             metadata=generation_info,
#    1739             output_version=self.output_version,
#    1740         )
#    1741     else:
# -> 1742         raw_response = self.client.with_raw_response.create(**payload)
#    1743         response = raw_response.parse()
#    1744 except openai.BadRequestError as e:
#
# File c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openai\_legacy_response.py:369, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     365 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     367 kwargs["extra_headers"] = extra_headers
# --> 369 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openai\resources\chat\completions\completions.py:1284, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1235 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1236 def create(
#    1237     self,
#    (...)   1281     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1282 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1283     validate_response_format(response_format)
# -> 1284     return self._post(
#    1285         "/chat/completions",
#    1286         body=maybe_transform(
#    1287             {
#    1288                 "messages": messages,
#    1289                 "model": model,
#    1290                 "audio": audio,
#    1291                 "frequency_penalty": frequency_penalty,
#    1292                 "function_call": function_call,
#    1293                 "functions": functions,
#    1294                 "logit_bias": logit_bias,
#    1295                 "logprobs": logprobs,
#    1296                 "max_completion_tokens": max_completion_tokens,
#    1297                 "max_tokens": max_tokens,
#    1298                 "metadata": metadata,
#    1299                 "modalities": modalities,
#    1300                 "moderation": moderation,
#    1301                 "n": n,
#    1302                 "parallel_tool_calls": parallel_tool_calls,
#    1303                 "prediction": prediction,
#    1304                 "presence_penalty": presence_penalty,
#    1305                 "prompt_cache_key": prompt_cache_key,
#    1306                 "prompt_cache_options": prompt_cache_options,
#    1307                 "prompt_cache_retention": prompt_cache_retention,
#    1308                 "reasoning_effort": reasoning_effort,
#    1309                 "response_format": response_format,
#    1310                 "safety_identifier": safety_identifier,
#    1311                 "seed": seed,
#    1312                 "service_tier": service_tier,
#    1313                 "stop": stop,
#    1314                 "store": store,
#    1315                 "stream": stream,
#    1316                 "stream_options": stream_options,
#    1317                 "temperature": temperature,
#    1318                 "tool_choice": tool_choice,
#    1319                 "tools": tools,
#    1320                 "top_logprobs": top_logprobs,
#    1321                 "top_p": top_p,
#    1322                 "user": user,
#    1323                 "verbosity": verbosity,
#    1324                 "web_search_options": web_search_options,
#    1325             },
#    1326             completion_create_params.CompletionCreateParamsStreaming
#    1327             if stream
#    1328             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1329         ),
#    1330         options=make_request_options(
#    1331             extra_headers=extra_headers,
#    1332             extra_query=extra_query,
#    1333             extra_body=extra_body,
#    1334             timeout=timeout,
#    1335             security={"bearer_auth": True},
#    1336         ),
#    1337         cast_to=ChatCompletion,
#    1338         stream=stream or False,
#    1339         stream_cls=Stream[ChatCompletionChunk],
#    1340     )
#
# File c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openai\_base_client.py:1360, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1351     warnings.warn(
#    1352         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1353         "Please pass raw bytes via the `content` parameter instead.",
#    1354         DeprecationWarning,
#    1355         stacklevel=2,
#    1356     )
#    1357 opts = FinalRequestOptions.construct(
#    1358     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1359 )
# -> 1360 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\gkhob\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\openai\_base_client.py:1133, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1130             err.response.read()
#    1132         log.debug("Re-raising status error")
# -> 1133         raise self._make_status_error_from_response(err.response) from None
#    1135     break
#    1137 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
