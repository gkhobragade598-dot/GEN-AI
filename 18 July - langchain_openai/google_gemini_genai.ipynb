# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = "GOOGLE_API_KEY"

model = init_chat_model("gemini-2.5-flash-lite", model_provider="google_genai")

# %%
# use the available newer model instance `llm` instead of the deprecated `model`
response = llm.invoke("about software jobs in 2026 to 2030?")
print(response.text)
# Out:
# The software job market from **2026 to 2030** will be defined by a massive paradox: **AI will write the basic code, yet the demand for human software talent will remain high—provided that talent evolves.**
#
# The era of "learn to code in 3 months and get a $150k junior developer job" is effectively over. However, the era of building complex, secure, and scalable digital systems is entering a golden age.
#
# Here is a detailed breakdown of what the software job market will look like between 2026 and 2030.
#
# ---
#
# ### 1. The Impact of AI: From Coders to "Software Pilots"
# By 2026–2030, Generative AI (like advanced descendants of Claude, GPT, and specialized coding agents) will handle most boilerplate code, standard unit tests, and routine bug fixes.
#
# * **The Death of the "Syntax Monkey":** Jobs focused purely on translating basic product requirements into standard CRUD (Create, Read, Update, Delete) applications will largely vanish or be heavily offshored/automated.
# ...

# %% [markdown]
# ## language translation

# %%
from langchain_core.messages import HumanMessage , SystemMessage

messages = [
    SystemMessage("Translate the following from English into odia language"),
    HumanMessage("how are you teams working on language with google gemini model?"),

]
llm.invoke(messages)
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'ଗୁଗଲ୍ ଜେମିନି (Google Gemini) ମଡେଲ୍ ସହିତ ଆପଣଙ୍କ ଟିମ୍ ଭାଷା (language) ଉପରେ କିପରି କାମ କରୁଛି?', 'extras': {'signature': 'EjQKMgERTTIPgB3b/Ld2MKnANeik8Q9HLg42+6GvTTELgmd0xM6c92YGHK2cN9+hwRu13nyE'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f95da-5fdc-7132-9ed5-94b7809ce028-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 23, 'output_tokens': 53, 'total_tokens': 76, 'input_token_details': {'cache_read': 0}})

# %%
response1 = llm.invoke(messages)

# %%
print(response1.text)
# Out:
# ଗୁଗଲ୍ ଜେମିନି (Google Gemini) ମଡେଲ୍ ସହିତ ଆପଣଙ୍କ ଟିମ୍ ଭାଷା (language) ନେଇ କିପରି କାମ କରୁଛନ୍ତି?

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage("Translate the following from marathi into english language"),
    HumanMessage("खूप छान झाला ")

]
llm.invoke(messages)
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Here are a few ways to translate "खूप छान झाला" into English, depending on the context:\n\n* **"It turned out very well."** (Most common for a project, food, or general task)\n* **"It was very good."** (General appreciation)\n* **"He became very nice/good."** (If referring to a person\'s behavior, though less common)', 'extras': {'signature': 'EjQKMgERTTIPYiM3SnSdevr87qZ6+Jlnhb+rZpg4UJAAErXBk2GQopqvR0CRvDZGV/UxGtbI'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f95df-f1c5-7043-8138-5106eb41f093-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 85, 'total_tokens': 100, 'input_token_details': {'cache_read': 0}})
